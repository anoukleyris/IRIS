# %%
import pandas as pd
data=pd.read_csv('IRIS_ Flower_Dataset .csv')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data.shape
# Out:
# (150, 5)

# %%
data.dropna(axis='columns')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data=data.fillna(data.median(), axis=0) 
print(data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]
# ...

# %%
print(data.isnull().sum())
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (147, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 147 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  147 non-null    float64
#  1   sepal_width   147 non-null    float64
#  2   petal_length  147 non-null    float64
#  3   petal_width   147 non-null    float64
#  4   species       147 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.9+ KB

# %%
data.describe() #moyenne, max... chaque colonne
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    147.000000   147.000000    147.000000   147.000000
# mean       5.856463     3.055782      3.780272     1.208844
# std        0.829100     0.437009      1.759111     0.757874
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
species_sepal_width=data.groupby('species')[['sepal_width']].mean() 
species_sepal_length=data.groupby('species')[['sepal_length']].mean()
species_petal_length=data.groupby('species')[['petal_length']].mean()  
species_petal_width=data.groupby('species')[['petal_width']].mean() 
print(species_sepal_width)
print(species_sepal_length)
print(species_petal_length)
print(species_petal_width)
# Out:
#                  sepal_width
# species
# Iris-setosa         3.431250
# Iris-versicolor     2.770000
# Iris-virginica      2.979592
#                  sepal_length
# species
# Iris-setosa          5.010417
# Iris-versicolor      5.936000
# Iris-virginica       6.604082
#                  petal_length
# species
# Iris-setosa          1.462500
# Iris-versicolor      4.260000
# Iris-virginica       5.561224
#                  petal_width
# species
# Iris-setosa         0.250000
# Iris-versicolor     1.326000
# Iris-virginica      2.028571

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data
sns.pairplot(data, hue='species', markers='+')
plt.show()

# %%
sns.boxplot(x = "species", y = "sepal_length", data = data)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
corr = data.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm') #grande corrélation, entre largeur des pétales et longueur des pétales il y a corrélation, plus d'autres exemples
plt.show()
# Out:
# /var/folders/4f/h8pcg8594_39w3f803d9r5_w0000gn/T/ipykernel_32691/1390514796.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()

# %%
sns.lineplot(x="sepal_width", y="sepal_length", data=data)
plt.title("sepal_length based on sepal_width")
plt.show()
sns.lineplot(x="petal_length", y="petal_width", data=data)
plt.title("petal_width based on petal_length")
plt.show()

sns.lineplot(x="sepal_width", y="petal_width", data=data)
plt.title("petal_length based on sepal_width")
plt.show()


sns.lineplot(x="sepal_length", y="petal_length", data=data)
plt.title("petal_length based on sepal_length")
plt.show()

# %%
iris = sns.load_dataset("iris")

# %%
sns.lineplot(x="petal_length", y="petal_width", hue="species", data=iris) 
plt.show()

# %%
sns.lineplot(x="sepal_length", y="petal_length", hue="species", data=iris) 
plt.show()

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

train_data, test_data = train_test_split(data, test_size=0.2, random_state=42) 
train_data, val_data = train_test_split(train_data, test_size=0.25, random_state=42)

feature = ['sepal_length', 'petal_length', 'petal_width','sepal_width']
target = 'species' 


X_train = train_data[feature]
y_train = train_data[target]

X_val = val_data[feature]
y_val = val_data[target]
X_test = test_data[feature]
y_test = test_data[target]

# Define the model
model = LogisticRegression()
model.fit(X_train, y_train)

param_grid = {'C': [0.001, 0.01, 0.1, 1, 10]}

grid_search = GridSearchCV(model, param_grid=param_grid, cv=5)

grid_search.fit(X_train, y_train)

print("Best hyperparameters: ", grid_search.best_params_)

y_test_pred = grid_search.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Test accuracy: ", test_accuracy)


def Survived(model,sepal_length, sepal_width, petal_length, petal_width):
    x = np.array([sepal_length, sepal_width, petal_length, petal_width]).reshape(1, 4)
    prediction = model.predict(x)
    probability = model.predict_proba(x)
    print("Prediction:", prediction)
    print("Probabilities:", probability)

Survived(model, 4,3,1.3,0.2)
# Out:
# /Users/anoukleyris/miniconda3/envs/py38_1/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/anoukleyris/miniconda3/envs/py38_1/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import learning_curve

dt = DecisionTreeClassifier()
train_sizes, train_scores, test_scores = learning_curve(
    dt, X_train, y_train, cv=5, n_jobs=-1,
    train_sizes=np.linspace(0.1, 1.0, 10),
    scoring='accuracy')
plt.figure(figsize=(8, 6))
plt.plot(train_sizes, np.mean(train_scores, axis=1), 'o-', label='Training score')
plt.plot(train_sizes, np.mean(test_scores, axis=1), 'o-', label='Validation score')
plt.xlabel('Training examples')
plt.ylabel('Score')
plt.legend(loc='best')
plt.title('Evolves of the accuracy test as a function of the number of samples')
plt.show()

# %%
from mlxtend.plotting import plot_decision_regions
from sklearn.datasets import load_iris
from sklearn.svm import SVC


iris = load_iris()
X = iris.data[:, [0, 2]]
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)#comme avant, 30% pour le test

clf = SVC(kernel='linear', C=1)

clf.fit(X_train, y_train)


plot_decision_regions(X_test, y_test, clf=clf, legend=2)

plt.xlabel('sepal length (cm)')
plt.ylabel('petal length (cm)')
plt.title('Decision boundaries SVM on Iris')


plt.show()

#les formes c'est pour chaque plante de chaque espèce et on a quaznd même une très bonne distinction entre les trois espèces sauf frontière vert orange
# Out:
# [5.1 1.4] [4.9 1.4] [4.7 1.3]
